# %%
#import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import warnings
warnings.filterwarnings('ignore')

# %%
#Laoding the datsaet
df=pd.read_csv('Twitter Dataset.csv')
df.head()
# Out:
#    id  label                                              tweet
# 0   1      0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1   2      0  Finally a transparant silicon case ^^ Thanks t...
# 2   3      0  We love this! Would you go? #talk #makememorie...
# 3   4      0  I'm wired I know I'm George I was made that wa...
# 4   5      1  What amazing service! Apple won't even talk to...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7920 entries, 0 to 7919
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      7920 non-null   int64
#  1   label   7920 non-null   int64
#  2   tweet   7920 non-null   object
# dtypes: int64(2), object(1)
# memory usage: 185.8+ KB

# %%
#preprocessing the datset
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for word in r:
        input_txt = re.sub(word, "", input_txt)
    return input_txt

# %%
#remove twitter handles
df['clean_tweet'] = np.vectorize(remove_pattern)(df['tweet'], "@[\w]*")

# %%
df.head()
# Out:
#    id  label                                              tweet  \
# 0   1      0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1   2      0  Finally a transparant silicon case ^^ Thanks t...
# 2   3      0  We love this! Would you go? #talk #makememorie...
# 3   4      0  I'm wired I know I'm George I was made that wa...
# 4   5      1  What amazing service! Apple won't even talk to...
#
#                                          clean_tweet
# 0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1  Finally a transparant silicon case ^^ Thanks t...
# 2  We love this! Would you go? #talk #makememorie...
# 3  I'm wired I know I'm George I was made that wa...
# 4  What amazing service! Apple won't even talk to...

# %%
# remove special characters, numbers and puctuations
df['clean_tweet'] = df['clean_tweet'].str.replace("[^a-zA-Z#]", " ")
df.head()
# Out:
#    id  label                                              tweet  \
# 0   1      0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1   2      0  Finally a transparant silicon case ^^ Thanks t...
# 2   3      0  We love this! Would you go? #talk #makememorie...
# 3   4      0  I'm wired I know I'm George I was made that wa...
# 4   5      1  What amazing service! Apple won't even talk to...
#
#                                          clean_tweet
# 0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1  Finally a transparant silicon case ^^ Thanks t...
# 2  We love this! Would you go? #talk #makememorie...
# 3  I'm wired I know I'm George I was made that wa...
# 4  What amazing service! Apple won't even talk to...

# %%
# remove the short words
df['clean_tweet'] = df['tweet']
df['clean_tweet'] = df['clean_tweet'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))
df.head()
# Out:
#    id  label                                              tweet  \
# 0   1      0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1   2      0  Finally a transparant silicon case ^^ Thanks t...
# 2   3      0  We love this! Would you go? #talk #makememorie...
# 3   4      0  I'm wired I know I'm George I was made that wa...
# 4   5      1  What amazing service! Apple won't even talk to...
#
#                                          clean_tweet
# 0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1  Finally transparant silicon case Thanks uncle ...
# 2  love this! Would #talk #makememories #unplug #...
# 3  wired know George made that #iphone #cute #dav...
# 4  What amazing service! Apple won't even talk ab...

# %%
# tokenization
tokenized_tweet = df['clean_tweet'].apply(lambda x: x.split())
tokenized_tweet.head()
# Out:
# 0    [#fingerprint, #Pregnancy, Test, https://goo.g...
# 1    [Finally, transparant, silicon, case, Thanks, ...
# 2    [love, this!, Would, #talk, #makememories, #un...
# 3    [wired, know, George, made, that, #iphone, #cu...
# 4    [What, amazing, service!, Apple, won't, even, ...
# Name: clean_tweet, dtype: object

# %%
# stemming
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()
tokenized_tweet = tokenized_tweet.apply(lambda sentence: [stemmer.stem(word) for word in sentence])
tokenized_tweet.head()
# Out:
# 0    [#fingerprint, #pregnanc, test, https://goo.gl...
# 1    [final, transpar, silicon, case, thank, uncl, ...
# 2    [love, this!, would, #talk, #makememori, #unpl...
# 3    [wire, know, georg, made, that, #iphon, #cute,...
# 4    [what, amaz, service!, appl, won't, even, talk...
# Name: clean_tweet, dtype: object

# %%
# combination into single sentence
for i in range(len(tokenized_tweet)):
    tokenized_tweet[i] = ' '.join(tokenized_tweet[i])
df['clean_tweet'] = tokenized_tweet
df.head()
# Out:
#    id  label                                              tweet  \
# 0   1      0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1   2      0  Finally a transparant silicon case ^^ Thanks t...
# 2   3      0  We love this! Would you go? #talk #makememorie...
# 3   4      0  I'm wired I know I'm George I was made that wa...
# 4   5      1  What amazing service! Apple won't even talk to...
#
#                                          clean_tweet
# 0  #fingerprint #pregnanc test https://goo.gl/h1m...
# 1  final transpar silicon case thank uncl #yay #s...
# 2  love this! would #talk #makememori #unplug #re...
# 3  wire know georg made that #iphon #cute #davent...
# 4  what amaz service! appl won't even talk about ...

# %%
# !pip install wordcloud

# %%
# visualize the frequent words
all_words = ' '.join([sentence for sentence in df['clean_tweet']])
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)
#plot the graph
plt.figure(figsize=(15, 8))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
#visualize the +ve words
all_words = ' '.join([sentence for sentence in df['clean_tweet'][df['label'] == 0]])
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)
#plot the graph
plt.figure(figsize=(15, 8))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
#visualize the +ve words
all_words = ' '.join([sentence for sentence in df['clean_tweet'][df['label'] == 1]])
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)
#plot the graph
plt.figure(figsize=(15, 8))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
# extract the hashtag
def hashtag_extract(x):
    hashtags = []
    # Loop over the words in the tweet
    for i in x:
        ht = re.findall(r"#(\w+)", i)
        hashtags.append(ht)
    return hashtags

# %%
 # extract hashtags from non racist
 ht_positive = hashtag_extract(df['clean_tweet'][df['label'] == 0])
 # extract hashtags from racist
 ht_negative = hashtag_extract(df['clean_tweet'][df['label'] == 1])

# %%
ht_positive[:5]
# Out:
# [['fingerprint',
#   'pregnanc',
#   'android',
#   'app',
#   'beauti',
#   'cute',
#   'health',
#   'iger',
#   'iphoneonli',
#   'iphonesia',
#   'iphon'],
#  ['yay', 'soni', 'xperia', 'sonyexperias'],
#  ['talk',
#   'makememori',
#   'unplug',
#   'relax',
#   'iphon',
#   'smartphon',
#   'wifi',
#   'connect'],
#  ['iphon', 'cute', 'daventri', 'home'],
#  ['instap', 'instadaili', 'soni', 'xperia', 'xperiaz']]

# %%
ht_positive = sum(ht_positive, [])
ht_negative = sum(ht_negative, [])

# %%
ht_positive[:5]
# Out:
# ['fingerprint', 'pregnanc', 'android', 'app', 'beauti']

# %%
freq=nltk.FreqDist(ht_positive)
d=pd.DataFrame({'Hashtag': list(freq.keys()),
                'Count': list(freq.values())})

# %%
d.head()
# Out:
#        Hashtag  Count
# 0  fingerprint      4
# 1     pregnanc      1
# 2      android    333
# 3          app    198
# 4       beauti    276

# %%
# Select top 10 hastags
d = d.nlargest(columns="Count", n = 10)
plt.figure(figsize=(16,5))
ax = sns.barplot(data=d, x= "Hashtag", y = "Count")
ax.set(ylabel = 'Count')
plt.show()

# %%
freq=nltk.FreqDist(ht_negative)
d=pd.DataFrame({'Hashtag': list(freq.keys()),
                'Count': list(freq.values())})
# Select top 10 hastags
d = d.nlargest(columns="Count", n = 10)
plt.figure(figsize=(16,5))
ax = sns.barplot(data=d, x= "Hashtag", y = "Count")
ax.set(ylabel = 'Count')
plt.show()

# %%
# feature Extraction
from sklearn.feature_extraction.text import CountVectorizer
bow_vectorizer = CountVectorizer(max_df=0.90, min_df=2, max_features=1000, stop_words='english')
bow = bow_vectorizer.fit_transform(df['clean_tweet'])

# %%
# bow[0].toarray()
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(bow, df['label'], random_state=42, test_size=0.25)

# %%
#model training
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, accuracy_score
# training
model = LogisticRegression()
model.fit(X_train, y_train)
#testing
pred = model.predict(X_test)
f1_score(y_test, pred)
# Out:
# 0.7871559633027524

# %%
accuracy_score(y_test,pred)
# Out:
# 0.8828282828282829

# %%
# use probability to get output
pred_prob = model.predict_proba(X_test)
pred = pred_prob[:,1] >= 0.3
pred = pred.astype(int)
f1_score(y_test, pred)
# Out:
# 0.8133333333333334

# %%
accuracy_score(y_test,pred)
# Out:
# 0.8868686868686869

# %%
pred_prob[0][1] >= 0.3
# Out:
# False

# %%
#saving the model
import pickle
pickle.dump(model, open('model.pkl', 'wb'))

# %%
pickle.dump(bow_vectorizer, open('vectorizer.pkl', 'wb'))

# %%
#using the model to preduct output
model = pickle.load(open('model.pkl', 'rb'))

# %%
# predicting the new data
X_new = input('Enter any tweet: ')
print(X_new)

# Vectorize the new input using the same vectorizer used during training
X_new_transformed = bow_vectorizer.transform([X_new])  # Keep this lines
# prediction = model.predict(X_new)  
prediction = model.predict(X_new_transformed)  # Use the transformed input instead
#print(prediction)
if (prediction[0] == 0):
  print('The predicted sentiment for the tweet is positive')
else:
  print('The predicted sentiment for the tweet is negative')
# Out:
# Enter any tweet:  f chief election commissioner has any honour left then after todays verdict by supreme court , he should resign and go home .Period!
# f chief election commissioner has any honour left then after todays verdict by supreme court , he should resign and go home .Period!
# The predicted sentiment for the tweet is negative
